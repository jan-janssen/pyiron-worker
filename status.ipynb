# %%
from pyiron import Project

# %%
pr = Project(".")

# %%
pr.job_table()
# Out:
#    id    status chemicalformula    job  subjob                  projectpath  \
# 0   2  finished          Al4000  lmp_0  /lmp_0  /Users/jan/pyiron/projects/
# 1   3  finished          Al4000  lmp_1  /lmp_1  /Users/jan/pyiron/projects/
# 2   4  finished          Al4000  lmp_2  /lmp_2  /Users/jan/pyiron/projects/
# 3   5  finished          Al4000  lmp_3  /lmp_3  /Users/jan/pyiron/projects/
# 4   6  finished          Al4000  lmp_4  /lmp_4  /Users/jan/pyiron/projects/
# 5   7  finished          Al4000  lmp_5  /lmp_5  /Users/jan/pyiron/projects/
# 6   8  finished          Al4000  lmp_6  /lmp_6  /Users/jan/pyiron/projects/
# 7   9  finished          Al4000  lmp_7  /lmp_7  /Users/jan/pyiron/projects/
# 8  10  finished          Al4000  lmp_8  /lmp_8  /Users/jan/pyiron/projects/
# 9  11  finished          Al4000  lmp_9  /lmp_9  /Users/jan/pyiron/projects/
#
#                           project                  timestart  \
# 0  2021/2021-10-14-worker/submit/ 2021-10-14 18:54:11.810352
# ...
