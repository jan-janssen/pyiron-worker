# %%
from pyiron_atomistics import Project

# %%
pr = Project(".")

# %%
pr.job_table()
# Out:
#    id    status chemicalformula    job  subjob projectpath  \
# 0   1  finished          Al4000  lmp_0  /lmp_0        None
# 1   2  finished          Al4000  lmp_1  /lmp_1        None
# 2   3  finished          Al4000  lmp_2  /lmp_2        None
# 3   4  finished          Al4000  lmp_3  /lmp_3        None
# 4   5  finished          Al4000  lmp_4  /lmp_4        None
# 5   6   aborted          Al4000  lmp_5  /lmp_5        None
# 6   7  finished          Al4000  lmp_6  /lmp_6        None
# 7   8  finished          Al4000  lmp_7  /lmp_7        None
# 8   9  finished          Al4000  lmp_8  /lmp_8        None
# 9  10  finished          Al4000  lmp_9  /lmp_9        None
#
#                 project                  timestart                   timestop  \
# 0  /home/jovyan/submit/ 2021-10-15 01:19:13.760087 2021-10-15 01:19:16.725434
# 1  /home/jovyan/submit/ 2021-10-15 01:19:14.635126 2021-10-15 01:19:16.620995
# 2  /home/jovyan/submit/ 2021-10-15 01:19:18.261171 2021-10-15 01:19:20.526474
# ...
