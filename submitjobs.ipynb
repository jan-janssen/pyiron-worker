# %%
from pyiron_atomistics import Project

# %%
pr = Project("submit")

# %%
structure = pr.create.structure.ase.bulk("Al", cubic=True)

# %%
structure.set_repeat([10, 10, 10])

# %%
for i in range(10):
    job = pr.create.job.Lammps("lmp_" + str(i))
    job.structure = structure
    job.server.run_mode.manual = True
    job.run()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_atomistics/lammps/base.py:262: UserWarning: No potential set via job.potential - use default potential, 1995--Angelo-J-E--Ni-Al-H--LAMMPS--ipr1
#   warnings.warn("No potential set via job.potential - use default potential, " + lst_of_potentials[0])
# The job lmp_0 was saved and received the ID: 1
# You have selected to start the job manually. To run it, go into the working directory /home/jovyan/submit/lmp_0_hdf5/lmp_0 and call 'python -m pyiron_base.cli wrapper -p /home/jovyan/submit/lmp_0_hdf5/lmp_0 -j 1 '
# The job lmp_1 was saved and received the ID: 2
# You have selected to start the job manually. To run it, go into the working directory /home/jovyan/submit/lmp_1_hdf5/lmp_1 and call 'python -m pyiron_base.cli wrapper -p /home/jovyan/submit/lmp_1_hdf5/lmp_1 -j 2 '
# The job lmp_2 was saved and received the ID: 3
# ...

# %%
pr.job_table()
# Out:
#    id     status chemicalformula    job  subjob projectpath  \
# 0   1  submitted          Al4000  lmp_0  /lmp_0        None
# 1   2  submitted          Al4000  lmp_1  /lmp_1        None
# 2   3  submitted          Al4000  lmp_2  /lmp_2        None
# 3   4  submitted          Al4000  lmp_3  /lmp_3        None
# 4   5  submitted          Al4000  lmp_4  /lmp_4        None
# 5   6  submitted          Al4000  lmp_5  /lmp_5        None
# 6   7  submitted          Al4000  lmp_6  /lmp_6        None
# 7   8  submitted          Al4000  lmp_7  /lmp_7        None
# 8   9  submitted          Al4000  lmp_8  /lmp_8        None
# 9  10  submitted          Al4000  lmp_9  /lmp_9        None
#
#                 project                  timestart timestop totalcputime  \
# 0  /home/jovyan/submit/ 2021-10-15 01:15:19.290125     None         None
# 1  /home/jovyan/submit/ 2021-10-15 01:15:20.107518     None         None
# 2  /home/jovyan/submit/ 2021-10-15 01:15:20.785202     None         None
# ...
