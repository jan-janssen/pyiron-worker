# %%
from pyiron import Project

# %%
pr = Project("submit")

# %%
structure = pr.create.structure.ase.bulk("Al", cubic=True)

# %%
structure.set_repeat([10, 10, 10])

# %%
for i in range(10):
    job = pr.create.job.Lammps("lmp_" + str(i))
    job.structure = structure
    job.server.run_mode.manual = True
    job.run()
# Out:
# /Users/jan/PycharmProjects/pyiron_atomistics/pyiron_atomistics/lammps/base.py:262: UserWarning: No potential set via job.potential - use default potential, 1995--Angelo-J-E--Ni-Al-H--LAMMPS--ipr1
#   warnings.warn("No potential set via job.potential - use default potential, " + lst_of_potentials[0])
# The job lmp_0 was saved and received the ID: 2
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_0_hdf5/lmp_0 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_0_hdf5/lmp_0 -j 2 '
# The job lmp_1 was saved and received the ID: 3
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_1_hdf5/lmp_1 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_1_hdf5/lmp_1 -j 3 '
# The job lmp_2 was saved and received the ID: 4
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_2_hdf5/lmp_2 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_2_hdf5/lmp_2 -j 4 '
# The job lmp_3 was saved and received the ID: 5
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_3_hdf5/lmp_3 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_3_hdf5/lmp_3 -j 5 '
# The job lmp_4 was saved and received the ID: 6
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_4_hdf5/lmp_4 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_4_hdf5/lmp_4 -j 6 '
# The job lmp_5 was saved and received the ID: 7
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_5_hdf5/lmp_5 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_5_hdf5/lmp_5 -j 7 '
# The job lmp_6 was saved and received the ID: 8
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_6_hdf5/lmp_6 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_6_hdf5/lmp_6 -j 8 '
# The job lmp_7 was saved and received the ID: 9
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_7_hdf5/lmp_7 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_7_hdf5/lmp_7 -j 9 '
# The job lmp_8 was saved and received the ID: 10
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_8_hdf5/lmp_8 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_8_hdf5/lmp_8 -j 10 '
# The job lmp_9 was saved and received the ID: 11
# You have selected to start the job manually. To run it, go into the working directory /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_9_hdf5/lmp_9 and call 'python -m pyiron_base.cli wrapper -p /Users/jan/pyiron/projects/2021/2021-10-14-worker/submit/lmp_9_hdf5/lmp_9 -j 11 '

# %%
pr.job_table()
# Out:
#    id     status chemicalformula    job  subjob                  projectpath  \
# 0   2  submitted          Al4000  lmp_0  /lmp_0  /Users/jan/pyiron/projects/
# 1   3  submitted          Al4000  lmp_1  /lmp_1  /Users/jan/pyiron/projects/
# 2   4  submitted          Al4000  lmp_2  /lmp_2  /Users/jan/pyiron/projects/
# 3   5  submitted          Al4000  lmp_3  /lmp_3  /Users/jan/pyiron/projects/
# 4   6  submitted          Al4000  lmp_4  /lmp_4  /Users/jan/pyiron/projects/
# 5   7  submitted          Al4000  lmp_5  /lmp_5  /Users/jan/pyiron/projects/
# 6   8  submitted          Al4000  lmp_6  /lmp_6  /Users/jan/pyiron/projects/
# 7   9  submitted          Al4000  lmp_7  /lmp_7  /Users/jan/pyiron/projects/
# 8  10  submitted          Al4000  lmp_8  /lmp_8  /Users/jan/pyiron/projects/
# 9  11  submitted          Al4000  lmp_9  /lmp_9  /Users/jan/pyiron/projects/
#
#                           project                  timestart timestop  \
# 0  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:49.502960     None
# 1  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:50.306781     None
# 2  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:51.464983     None
# 3  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:53.074091     None
# 4  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:54.488412     None
# 5  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:55.995265     None
# 6  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:57.834132     None
# 7  2021/2021-10-14-worker/submit/ 2021-10-14 18:52:59.674950     None
# 8  2021/2021-10-14-worker/submit/ 2021-10-14 18:53:01.514407     None
# 9  2021/2021-10-14-worker/submit/ 2021-10-14 18:53:03.798988     None
#
#   totalcputime                    computer hamilton hamversion parentid  \
# 0         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 1         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 2         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 3         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 4         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 5         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 6         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 7         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 8         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
# 9         None  pyiron@MacBook-Pro.local#1   Lammps        0.1     None
#
#   masterid
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
